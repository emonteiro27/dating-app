# %% [markdown]
# # Dating app

# %%
#import the necessary libraries

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
#upload the csv files

users_inst = pd.read_csv('./raw_data/lovoo_v3_users_instances.csv')
users_api = pd.read_csv('./raw_data/lovoo_v3_users_api-results.csv')
users_inter = pd.read_csv('./raw_data/interests-of-users-by-age.csv')

# %%
users_inst.head()
# Out:
#   gender  age         name  counts_pictures  counts_profileVisits  \
# 0      F   25        daeni                4                  8279
# 1      F   22  italiana 92                5                   663
# 2      F   20   Qqkwmdowlo                3                 22187
# 3      F   24     Baby dee               18                  7339
# 4      F   24         Anna               13                 18672
#
#    counts_kisses  flirtInterests_chat  flirtInterests_friends  \
# 0            239                 True                    True
# 1             13                 True                    True
# 2           1015                 True                    True
# 3            180                 True                   False
# 4            492                False                    True
#
#    flirtInterests_date  connectedToFacebook  ...  hasBirthday  highlighted  \
# 0                 True                False  ...        False        False
# ...

# %%
users_api.head()
# Out:
#   gender genderLooking  age          name  counts_details  counts_pictures  \
# 0      F             M   25         daeni            1.00                4
# 1      F             M   22   italiana 92            0.85                5
# 2      F             M   21       Lauraaa            0.00                4
# 3      F          none   20    Qqkwmdowlo            0.12                3
# 4      F             M   21  schaessie {3            0.15               12
#
#    counts_profileVisits  counts_kisses  counts_fans  counts_g  ...  \
# 0                  8279            239            0         3  ...
# 1                   663             13            0         0  ...
# 2                  1369             88            0         2  ...
# 3                 22187           1015            2         3  ...
# 4                 35262           1413            9        12  ...
#
#    shareProfileEnabled        lastOnlineDate  lastOnlineTime birthd crypt  \
# ...

# %%
users_inter.head()
# Out:
#    age  nbusers  percentwantchats  percentwantfriends  percentwantdates  \
# 0   18        1               0.0                 0.0               0.0
# 1   19      523              65.8                62.5              34.2
# 2   20      524              67.6                64.9              37.2
# 3   21      603              64.0                63.0              35.7
# 4   22      720              59.9                60.6              40.3
#
#    meankissesreceived  meanvisitsreceived  meanfollowers  meanlanguagesknown  \
# 0                   0                 0.0            0.0                1.00
# 1                 179              4279.5            2.6                1.15
# 2                 208              4809.5            1.8                1.12
# 3                 167              4093.0            2.1                1.12
# 4                 134              3302.9            1.7                1.07
#
# ...

# %% [markdown]
# ## Data analysis

# %%
print(f'users_inst shape: {users_inst.shape}')
print(f'users_api shape: {users_api.shape}')
print(f'users_inter shape: {users_inter.shape}')
# Out:
# users_inst shape: (2919, 39)
# users_api shape: (3973, 42)
# users_inter shape: (11, 16)

# %%
print(f"users_inst unique names: {users_inst['name'].nunique()}")
print(f"users_api unique names: {users_api['name'].nunique()}")
# Out:
# users_inst unique names: 2182
# users_api unique names: 2843

# %%
print(f'users_inst duplicates: {users_inst.duplicated().sum()}')
print(f'users_api duplicates: {users_api.duplicated().sum()}')
print(f'users_inter duplicates: {users_inter.duplicated().sum()}')
# Out:
# users_inst duplicates: 0
# users_api duplicates: 0
# users_inter duplicates: 0

# %%
non_unique_names = users_inst[users_inst['name'].duplicated(keep=False)]
non_unique_names
# Out:
#      gender  age     name  counts_pictures  counts_profileVisits  \
# 4         F   24     Anna               13                 18672
# 12        F   25      Lia               13                 26842
# 15        F   25     tina                7                  3413
# 16        F   19      mel               13                  8310
# 25        F   24  Vanessa                3                 51339
# ...     ...  ...      ...              ...                   ...
# 2914      F   20    Ma**e                8                  1101
# 2915      F   23   Eni**n                8                  8681
# 2916      F   23   Eni**n                8                  8682
# 2917      F   23   Eni**n                8                  8702
# 2918      F   23   Eni**n                9                  8904
#
#       counts_kisses  flirtInterests_chat  flirtInterests_friends  \
# 4               492                False                    True
# ...

# %%
non_unique_names_2 = users_api[users_api['name'].duplicated(keep=False)]
non_unique_names_2
# Out:
#      gender genderLooking  age      name  counts_details  counts_pictures  \
# 6         F          none   24      Anna            0.65               13
# 12        F             M   22  Nathalie            0.73               22
# 15        F             M   25       Lia            0.58               13
# 16        F             M   21   Vanessa            0.69                5
# 19        F             M   25      tina            0.92                7
# ...     ...           ...  ...       ...             ...              ...
# 3968      F             M   21      B**f            0.85                1
# 3969      F             M   20     Ma**e            1.00                8
# 3970      F             M   20     Ma**e            1.00                8
# 3971      F             M   23    Eni**n            0.96                8
# 3972      F             M   23    Eni**n            0.96                9
#
#       counts_profileVisits  counts_kisses  counts_fans  counts_g  ...  \
# ...
